# %%
# Import required libraries
import xarray as xr
from pathlib import Path
import numpy as np
import datetime
import pandas as pd
import cfgrib
import os
import shutil
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Read the original datacube
ds_original = xr.open_dataset(Path.home() / 'hdd1/skondylatos/uc3/greece_big_zipped.nc')

# %%
ds_original
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 4560, x: 1253, y: 983)
# Coordinates:
#   * time                     (time) datetime64[ns] 2009-03-06T10:00:00 ... 20...
#   * x                        (x) float64 18.7 18.71 18.72 ... 28.88 28.89 28.9
#   * y                        (y) float64 42.3 42.29 42.28 ... 34.32 34.31 34.3
#     band                     int64 ...
#     spatial_ref              int64 ...
# Data variables: (12/90)
#     1 km 16 days NDVI        (time, y, x) float32 ...
#     1 km 16 days EVI         (time, y, x) float32 ...
#     ET_500m                  (time, y, x) float32 ...
#     LST_Day_1km              (time, y, x) float32 ...
#     LST_Night_1km            (time, y, x) float32 ...
#     Fpar_500m                (time, y, x) float32 ...
#     ...                       ...
#     population_density_2016  (y, x) float32 ...
#     population_density_2017  (y, x) float32 ...
#     population_density_2018  (y, x) float32 ...
# ...

# %%
ds = xr.open_dataset(Path.home() / 'jh-shared/METEO_DATA/PAPOU_DATA/BOLAM_DATA/BOL-H_2021050100_000.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (y: 166, x: 198, nv4: 4, height: 4, height_2: 1, time: 1)
# Coordinates:
#     lon        (y, x) float32 ...
#     lat        (y, x) float32 ...
#   * height     (height) float64 10.0 50.0 80.0 100.0
#   * height_2   (height_2) float64 2.0
#   * time       (time) datetime64[ns] 2021-05-01
# Dimensions without coordinates: y, x, nv4
# Data variables:
#     lon_bnds   (y, x, nv4) float32 ...
#     lat_bnds   (y, x, nv4) float32 ...
#     apcp       (time, y, x) float32 ...
#     acpcp      (time, y, x) float32 ...
#     10u        (time, height, y, x) float32 ...
#     10v        (time, height, y, x) float32 ...
#     t_2m       (time, height_2, y, x) float32 ...
#     relhum_2m  (time, height_2, y, x) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.5.4 (http://code.zmaw.de/p...
#     Conventions:  CF-1.4
#     history:      Tue Feb 22 10:05:15 2022: cdo -sellonlatbox,16,30,34,43 -se...
# ...

# %%
grid_x, grid_y = np.meshgrid(ds_original['x'], ds_original['y'])

# %%
coords = np.stack([ds['lon'].values, ds['lat'].values], axis=2)

# %%
coords = coords.reshape(166*198,2)

# %%
t2m = ds['t_2m'].squeeze().values.reshape(166*198)

# %%
from scipy.interpolate import griddata
gd = griddata(coords, t2m, (grid_x, grid_y), method='nearest')

# %%
# Mia matia sta prota coords
for i in range(198):
    print(coords[i])
# Out:
# [16.057823 34.029896]
# [16.127764 34.029823]
# [16.197704 34.029694]
# [16.267643 34.02951 ]
# [16.337584 34.029274]
# [16.407522 34.028976]
# [16.477459 34.02863 ]
# [16.547398 34.02822 ]
# [16.617334 34.027763]
# [16.68727 34.02725]
# [16.757204 34.026676]
# [16.827137 34.02605 ]
# [16.897068 34.025368]
# [16.967   34.02463]
# [17.036928 34.02384 ]
# [17.106855 34.022995]
# [17.176783 34.02209 ]
# [17.246706 34.021133]
# [17.316628 34.020123]
# [17.386547 34.019054]
# [17.456465 34.01793 ]
# [17.52638 34.01675]
# [17.596294 34.01552 ]
# [17.666204 34.01423 ]
# [17.736113 34.012882]
# [17.806017 34.011486]
# [17.87592 34.01003]
# [17.94582 34.00852]
# [18.015717 34.006954]
# [18.08561  34.005333]
# [18.155499 34.00366 ]
# [18.225386 34.001926]
# [18.295269 34.00014 ]
# [18.365149 33.998302]
# [18.435026 33.996407]
# [18.504898 33.994453]
# [18.574766 33.992447]
# [18.64463  33.990383]
# [18.71449 33.98827]
# [18.784346 33.986095]
# [18.854198 33.983868]
# [18.924046 33.981586]
# ...

# %%
coords[0]
# Out:
# array([16.057823, 34.029896], dtype=float32)

# %%
coords[1]
# Out:
# array([16.127764, 34.029823], dtype=float32)

# %%
coords[197]
# Out:
# array([29.698545, 32.95887 ], dtype=float32)

# %%
coords[198]
# Out:
# array([16.05788 , 34.089897], dtype=float32)

# %%
#Data array me to gd
da = xr.DataArray(
    data=gd,
    dims=["y", "x"],
    coords=dict(
        y=ds_original['y'],
        x=ds_original['x']
    )
)

# %%
da
# Out:
# <xarray.DataArray (y: 983, x: 1253)>
# array([[293.06616, 293.06616, 293.06616, ..., 290.2273 , 290.2273 ,
#         290.2273 ],
#        [293.06616, 293.06616, 293.06616, ..., 290.2273 , 290.2273 ,
#         290.2273 ],
#        [293.06616, 293.06616, 293.06616, ..., 290.2273 , 290.2273 ,
#         290.2273 ],
#        ...,
#        [295.3025 , 295.3025 , 295.3025 , ..., 295.76636, 295.76636,
#         295.9939 ],
#        [295.3025 , 295.3025 , 295.3025 , ..., 295.76636, 295.76636,
#         295.9939 ],
#        [295.3025 , 295.3025 , 295.3025 , ..., 295.76636, 295.76636,
#         295.9939 ]], dtype=float32)
# Coordinates:
#   * y        (y) float64 42.3 42.29 42.28 42.27 42.27 ... 34.33 34.32 34.31 34.3
#   * x        (x) float64 18.7 18.71 18.72 18.73 18.73 ... 28.87 28.88 28.89 28.9

# %%
da.plot()

# %%
ds['t_2m'].sel(x = slice(30,180), y = slice(10,140)).plot()

# %%
da.sel(x = slice(22,24)).plot()

# %%
ds['t_2m'].sel(x = slice(75,125)).plot()

# %%
da.max()
# Out:
# <xarray.DataArray ()>
# array(299.22046, dtype=float32)

# %%
ds['t_2m'].max()
# Out:
# <xarray.DataArray 't_2m' ()>
# array(299.2478, dtype=float32)

# %%
da.min()
# Out:
# <xarray.DataArray ()>
# array(283.57007, dtype=float32)

# %%
ds['t_2m'].min()
# Out:
# <xarray.DataArray 't_2m' ()>
# array(280.75952, dtype=float32)

# %%
da.mean()
# Out:
# <xarray.DataArray ()>
# array(291.07404, dtype=float32)

# %%
ds['t_2m'].mean()
# Out:
# <xarray.DataArray 't_2m' ()>
# array(290.9092, dtype=float32)

# %%
plt.figure(figsize=(12,8))
plt.title("t2m")
plt.hist([ds['t_2m'].values.ravel(), da.values.ravel()])
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("t2m")
plt.hist(ds['t_2m'].values.ravel())
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("t2m")
plt.hist(da.values.ravel())
plt.show()

# %%
ds_original['x'][0]
# Out:
# <xarray.DataArray 'x' ()>
# array(18.70211622)
# Coordinates:
#     x            float64 18.7
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X

# %%
ds_original['y'][0]
# Out:
# <xarray.DataArray 'y' ()>
# array(42.29919488)
# Coordinates:
#     y            float64 42.3
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  latitude
#     long_name:      latitude
#     units:          degrees_north
#     axis:           Y

# %%
da.sel(x = 18.702116, y = 42.299195, method = 'nearest')
# Out:
# <xarray.DataArray ()>
# array(293.06616, dtype=float32)
# Coordinates:
#     y        float64 42.3
#     x        float64 18.7

# %%
def find_nearest(a, val):
    return np.abs(a - val).argmin()

# %%
def find_idx_lat_lon(x, y, variable):
    x_idx = np.apply_along_axis(find_nearest, axis = 1, arr = ds[variable].lon.values, val = x)
    empty_list = []
    for i, value in enumerate(x_idx):
        empty_list.append(ds[variable].sel(x = value, y = i).lat.values.item())

    o = np.array(empty_list)
    idx = find_nearest_9(o, y)
    print(x_idx[idx], idx)

# %%
find_idx_lat_lon(18.702116, 42.299195, 't_2m')
# Out:
# 33 138

# %%
ds['t_2m'].sel(x = 33, y = 138)
# Out:
# <xarray.DataArray 't_2m' (time: 1, height_2: 1)>
# array([[293.06616]], dtype=float32)
# Coordinates:
#     lon       float32 18.72
#     lat       float32 42.27
#   * height_2  (height_2) float64 2.0
#   * time      (time) datetime64[ns] 2021-05-01
# Attributes:
#     long_name:  2m Temperature
#     units:      K
#     param:      0.0.0

# %%
ds_original['x'][15]
# Out:
# <xarray.DataArray 'x' ()>
# array(18.82428658)
# Coordinates:
#     x            float64 18.82
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X

# %%
ds_original['y'][46]
# Out:
# <xarray.DataArray 'y' ()>
# array(41.9245391)
# Coordinates:
#     y            float64 41.92
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  latitude
#     long_name:      latitude
#     units:          degrees_north
#     axis:           Y

# %%
da.sel(x = 18.82428658, y = 41.9245391, method = 'nearest')
# Out:
# <xarray.DataArray ()>
# array(292.17163, dtype=float32)
# Coordinates:
#     y        float64 41.92
#     x        float64 18.82

# %%
find_idx_lat_lon(18.82428658, 41.9245391, 't_2m')
# Out:
# 34 132

# %%
ds['t_2m'].sel(x = 34, y = 132)
# Out:
# <xarray.DataArray 't_2m' (time: 1, height_2: 1)>
# array([[292.17163]], dtype=float32)
# Coordinates:
#     lon       float32 18.79
#     lat       float32 41.91
#   * height_2  (height_2) float64 2.0
#   * time      (time) datetime64[ns] 2021-05-01
# Attributes:
#     long_name:  2m Temperature
#     units:      K
#     param:      0.0.0

# %%
ds_original['x'][566]
# Out:
# <xarray.DataArray 'x' ()>
# array(23.3120112)
# Coordinates:
#     x            float64 23.31
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X

# %%
ds_original['y'][888]
# Out:
# <xarray.DataArray 'y' ()>
# array(35.06670948)
# Coordinates:
#     y            float64 35.07
#     band         int64 1
#     spatial_ref  int64 0
# Attributes:
#     standard_name:  latitude
#     long_name:      latitude
#     units:          degrees_north
#     axis:           Y

# %%
da.sel(x = 23.3120112, y = 35.06670948, method = 'nearest')
# Out:
# <xarray.DataArray ()>
# array(295.02515, dtype=float32)
# Coordinates:
#     y        float64 35.07
#     x        float64 23.31

# %%
find_idx_lat_lon(23.3120112, 35.06670948, 't_2m')
# Out:
# 102 22

# %%
ds['t_2m'].sel(x = 102, y = 22)
# Out:
# <xarray.DataArray 't_2m' (time: 1, height_2: 1)>
# array([[295.02515]], dtype=float32)
# Coordinates:
#     lon       float32 23.33
#     lat       float32 35.05
#   * height_2  (height_2) float64 2.0
#   * time      (time) datetime64[ns] 2021-05-01
# Attributes:
#     long_name:  2m Temperature
#     units:      K
#     param:      0.0.0
