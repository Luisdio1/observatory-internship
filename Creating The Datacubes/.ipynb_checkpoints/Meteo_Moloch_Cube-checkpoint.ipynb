# %%
# Import required libraries
import xarray as xr
from pathlib import Path
import numpy as np
import datetime
import pandas as pd
import cfgrib
import os
import shutil
from datetime import datetime
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

# %%
# Read the original datacube
ds_original = xr.open_dataset(Path.home() / 'hdd1/skondylatos/uc3/greece_big_zipped.nc')

# %%
ds_original
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 4560, x: 1253, y: 983)
# Coordinates:
#   * time                     (time) datetime64[ns] 2009-03-06T10:00:00 ... 20...
#   * x                        (x) float64 18.7 18.71 18.72 ... 28.88 28.89 28.9
#   * y                        (y) float64 42.3 42.29 42.28 ... 34.32 34.31 34.3
#     band                     int64 ...
#     spatial_ref              int64 ...
# Data variables: (12/90)
#     1 km 16 days NDVI        (time, y, x) float32 ...
#     1 km 16 days EVI         (time, y, x) float32 ...
#     ET_500m                  (time, y, x) float32 ...
#     LST_Day_1km              (time, y, x) float32 ...
#     LST_Night_1km            (time, y, x) float32 ...
#     Fpar_500m                (time, y, x) float32 ...
#     ...                       ...
#     population_density_2016  (y, x) float32 ...
#     population_density_2017  (y, x) float32 ...
#     population_density_2018  (y, x) float32 ...
# ...

# %%
ds1 = xr.open_dataset('/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050200.grib', engine = 'cfgrib', indexpath = '', 
                     backend_kwargs={'filter_by_keys': { 'stepUnits': 0,'typeOfLevel' :  'heightAboveGround', 'level' : 2}})
# Out:
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ...

# %%
ds2 = xr.open_dataset('/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib', engine = 'cfgrib', indexpath = '', 
                     backend_kwargs={'filter_by_keys': { 'stepUnits': 1, 'typeOfLevel' :  'heightAboveGround', 'level' : 10}})
# Out:
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ECCODES ERROR   :  unable to convert endStep in stepUnits
# ...

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:            (step: 49, latitude: 500, longitude: 725)
# Coordinates:
#     time               datetime64[ns] ...
#   * step               (step) timedelta64[ns] 00:00:00 ... 2 days 00:00:00
#     heightAboveGround  float64 ...
#   * latitude           (latitude) float64 33.0 33.02 33.04 ... 42.94 42.96 42.98
#   * longitude          (longitude) float64 17.5 17.52 17.54 ... 31.96 31.98
#     valid_time         (step) datetime64[ns] ...
# Data variables:
#     u10                (step, latitude, longitude) float32 ...
#     v10                (step, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cnmc
#     GRIB_centreDescription:  Rome
#     GRIB_subCentre:          102
#     Conventions:             CF-1.7
#     institution:             Rome
#     history:                 2022-09-16T21:44 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:            (step: 48, latitude: 500, longitude: 725)
# Coordinates:
#     time               datetime64[ns] ...
#   * step               (step) timedelta64[ns] 00:30:00 ... 1 days 23:30:00
#     heightAboveGround  float64 ...
#   * latitude           (latitude) float64 33.0 33.02 33.04 ... 42.94 42.96 42.98
#   * longitude          (longitude) float64 17.5 17.52 17.54 ... 31.96 31.98
#     valid_time         (step) datetime64[ns] ...
# Data variables:
#     t2m                (step, latitude, longitude) float32 ...
#     r2                 (step, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cnmc
#     GRIB_centreDescription:  Rome
#     GRIB_subCentre:          102
#     Conventions:             CF-1.7
#     institution:             Rome
#     history:                 2022-09-16T22:56 GRIB to CDM+CF via cfgrib-0.9.9...

# %%
x = xr.merge([ds1, ds2], compat = 'override')

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:            (step: 49, latitude: 500, longitude: 725)
# Coordinates:
#     time               datetime64[ns] 2021-05-01
#   * step               (step) timedelta64[ns] 00:00:00 ... 2 days 00:00:00
#     heightAboveGround  float64 2.0
#   * latitude           (latitude) float64 33.0 33.02 33.04 ... 42.94 42.96 42.98
#   * longitude          (longitude) float64 17.5 17.52 17.54 ... 31.96 31.98
#     valid_time         (step) datetime64[ns] 2021-05-01 ... 2021-05-03
# Data variables:
#     t2m                (step, latitude, longitude) float32 ...
#     r2                 (step, latitude, longitude) float32 ...
#     u10                (step, latitude, longitude) float32 ...
#     v10                (step, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             cnmc
#     GRIB_centreDescription:  Rome
#     GRIB_subCentre:          102
#     Conventions:             CF-1.7
# ...

# %%
ds1.t2m.isnull()
# Out:
# <xarray.DataArray 't2m' (step: 48, latitude: 500, longitude: 725)>
# array([[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
# ...

# %%
ds = cfgrib.open_file('/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib', 
                     filter_by_keys = { 'stepUnits': 0, 'typeOfLevel' :  'heightAboveGround', 'level' : 10})
# Out:
# Can't create file '/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib.9810b.idx'
# Traceback (most recent call last):
#   File "/mnt/hdd1/diogenis/observatory/meteo/lib/python3.7/site-packages/cfgrib/messages.py", line 343, in from_indexpath_or_filestream
#     with compat_create_exclusive(indexpath) as new_index_file:
#   File "/opt/tljh/user/lib/python3.7/contextlib.py", line 112, in __enter__
#     return next(self.gen)
#   File "/mnt/hdd1/diogenis/observatory/meteo/lib/python3.7/site-packages/cfgrib/messages.py", line 264, in compat_create_exclusive
#     fd = os.open(path, os.O_WRONLY | os.O_CREAT | os.O_EXCL)
# PermissionError: [Errno 13] Permission denied: '/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib.9810b.idx'
# Can't read index file '/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib.9810b.idx'
# Traceback (most recent call last):
# ...

# %%
ds
# Out:
# Dataset(dimensions={'step': 48, 'latitude': 500, 'longitude': 725}, variables={'time': Variable(dimensions=(), data=1619827200), 'step': Variable(dimensions=('step',), data=array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#        11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#        22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#        33.5, 34.5, 35.5, 36.5, 37.5, 38.5, 39.5, 40.5, 41.5, 42.5, 43.5,
#        44.5, 45.5, 46.5, 47.5])), 'heightAboveGround': Variable(dimensions=(), data=10.0), 'latitude': Variable(dimensions=('latitude',), data=array([33.  , 33.02, 33.04, 33.06, 33.08, 33.1 , 33.12, 33.14, 33.16,
#        33.18, 33.2 , 33.22, 33.24, 33.26, 33.28, 33.3 , 33.32, 33.34,
#        33.36, 33.38, 33.4 , 33.42, 33.44, 33.46, 33.48, 33.5 , 33.52,
#        33.54, 33.56, 33.58, 33.6 , 33.62, 33.64, 33.66, 33.68, 33.7 ,
#        33.72, 33.74, 33.76, 33.78, 33.8 , 33.82, 33.84, 33.86, 33.88,
# ...

# %%
sorted(ds.dimensions.items())
# Out:
# [('latitude', 500), ('longitude', 725), ('step', 49)]

# %%
sorted(ds.variables)
# Out:
# ['heightAboveGround',
#  'latitude',
#  'longitude',
#  'step',
#  'time',
#  'u10',
#  'v10',
#  'valid_time']

# %%
var = ds.variables['u10']

# %%
var
# Out:
# Variable(dimensions=('step', 'latitude', 'longitude'), data=OnDiskArray(stream=FileStream(path='/home/jupyter-diogenis/jh-shared/METEO_DATA/PAPOU_DATA/MOLOCH_DATA/moloch_21050100.grib', errors='warn'), shape=(49, 500, 725), missing_value=9999))

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# /tmp/ipykernel_3449102/709541293.py in <module>
# ----> 1 var.data[:, :, :, :, :].mean()
#
# /mnt/hdd1/diogenis/observatory/meteo/lib/python3.7/site-packages/cfgrib/dataset.py in __getitem__(self, item)
#     334         header_item = [{ix: i for i, ix in enumerate(it)} for it in header_item_list]
#     335         array_field_shape = tuple(len(l) for l in header_item_list) + self.shape[-self.geo_ndim :]
# --> 336         array_field = np.full(array_field_shape, fill_value=np.nan, dtype="float32")
#     337         with open(self.stream.path, "rb") as file:
#     338             for header_indexes, offset in self.offsets.items():
#
# /mnt/hdd1/diogenis/observatory/meteo/lib/python3.7/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order, like)
#     341         fill_value = asarray(fill_value)
# ...
